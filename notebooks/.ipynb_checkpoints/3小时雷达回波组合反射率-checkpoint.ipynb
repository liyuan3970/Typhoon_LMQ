# %% [markdown]
# # 逐6分钟的雷达回波

# %%
# %matplotlib inline
import matplotlib 
import cinrad

file = '/home/liyuan3970/Data/data/meto_data/radar_typhoon_liqima/wenzhou_rada/08/'
f = cinrad.io.CinradReader(file+'Z_RADR_I_Z9577_20190808000200_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
r = f.get_data(tilt_number, data_radius, data_dtype)
print(r)


# %matplotlib inline
rl = list(f.iter_tilt(230, 'REF'))
#rl = list(f.iter_tilt(230, 'VEL'))
cr = cinrad.easycalc.quick_cr(rl)
fig = cinrad.visualize.PPI(cr, dpi=50)
#plt.show()
# Out:
# <Datatype: REF Station name: 温州 Scan time: 2019-08-08 00:02:11.812000 Elevation angle: 0.50 Range: 230>
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
import os
path = "/home/liyuan3970/Data/data/meto_data/radar_typhoon_liqima/wenzhou_rada/after_land/"
file = os.listdir(path)
file.sort()

def plot(filename):
    file = path +filename
    f = cinrad.io.CinradReader(file)
    tilt_number = 0
    data_radius = 230
    data_dtype = 'REF' # stands for reflectivity
    r = f.get_data(tilt_number, data_radius, data_dtype)
    rl = list(f.iter_tilt(230, 'REF'))
    #rl = list(f.iter_tilt(230, 'VEL'))
    cr = cinrad.easycalc.quick_cr(rl)
    fig = cinrad.visualize.PPI(cr, dpi=50)    
    
    pass
for i in file:
    pass
# Out:
# ['Z_RADR_I_Z9577_20190809150400_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809151000_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809151600_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809152100_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809152700_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809153300_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809153800_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809154400_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809154900_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809155500_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809160100_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809160700_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809161200_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809161800_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809162300_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809162900_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809163500_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809164000_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809164600_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809165200_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809165700_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809170300_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809170800_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809171400_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809172000_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809172500_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809173100_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809173600_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809174200_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809174800_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809175300_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809175900_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809180500_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809181000_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809181600_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809182100_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809182700_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809183300_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809183800_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809184400_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809184900_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809185500_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809190100_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809190600_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809191200_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809191700_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809192300_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809192900_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809193400_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809194000_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809194600_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809195100_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809195700_O_DOR_SA_CAP.bin.bz2', 'Z_RADR_I_Z9577_20190809200200_O_DOR_SA_CAP.bin.bz2']
