# %%
import numpy as np
from PIL import Image
import os
import time
import matplotlib.pyplot as plt
import imageio
#from moviepy.editor import ImageSequenceClip

path = "/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/"
file = os.listdir(path)
file.sort()
for i in range(len(file)):
    file[i] = path +file[i]
    #print(i)
    
#print(file)
# Out:
# ['/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808000200_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808000700_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808001900_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808003500_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808004100_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808012000_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808012600_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808013200_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808013700_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808014300_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808014800_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808020500_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808021100_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808021600_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808022800_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808030100_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808031300_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808031800_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808032900_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808033500_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808034100_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808034600_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808035200_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808035700_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808040300_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808040900_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808041400_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808042000_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808043700_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808044200_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808045400_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808053300_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808053900_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808054400_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808055000_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808055500_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808060700_O_DOR_SA_CAP.bin.bz2.png', '/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/Z_RADR_I_Z9577_20190808062400_O_DOR_SA_CAP.bin.bz2.png', '/home/li ...

# %%
import imageio


def create_gif(image_list, gif_name, duration=0.35):
    frames = []
    for image_name in image_list:
        frames.append(imageio.imread(image_name))
    imageio.mimsave(gif_name, frames, 'GIF', duration=duration)
    return


def main():
    image_list =file
    gif_name = 'test.gif'
    duration = 0.35
    create_gif(image_list, gif_name, duration)


if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-a6552a882563> in <module>
#      18
#      19 if __name__ == '__main__':
# ---> 20     main()
#
# <ipython-input-14-a6552a882563> in main()
#      14     gif_name = 'test.gif'
#      15     duration = 0.35
# ---> 16     create_gif(image_list, gif_name, duration)
#      17
#      18
#
# <ipython-input-14-a6552a882563> in create_gif(image_list, gif_name, duration)
#       5     frames = []
#       6     for image_name in image_list:
# ----> 7         frames.append(imageio.imread(image_name))
#       8     imageio.mimsave(gif_name, frames, 'GIF', duration=duration)
#       9     return
#
# ~/anaconda3/lib/python3.7/site-packages/imageio/core/functions.py in imread(uri, format, **kwargs)
#     219
#     220     # Get reader and read first
# --> 221     reader = read(uri, format, "i", **kwargs)
#     222     with reader:
#     223         return reader.get_data(0)
#
# ~/anaconda3/lib/python3.7/site-packages/imageio/core/functions.py in get_reader(uri, format, mode, **kwargs)
#     128
#     129     # Create request object
# --> 130     request = Request(uri, "r" + mode, **kwargs)
#     131
#     132     # Get format
#
# ~/anaconda3/lib/python3.7/site-packages/imageio/core/request.py in __init__(self, uri, mode, **kwargs)
#     123
#     124         # Parse what was given
# --> 125         self._parse_uri(uri)
#     126
#     127         # Set extension
#
# ~/anaconda3/lib/python3.7/site-packages/imageio/core/request.py in _parse_uri(self, uri)
#     271                 # Reading: check that the file exists (but is allowed a dir)
#     272                 if not os.path.exists(fn):
# --> 273                     raise FileNotFoundError("No such file: '%s'" % fn)
#     274             else:
#     275                 # Writing: check that the directory to write to does exist
#
# FileNotFoundError: No such file: '/home/liyuan3970/Typhoon_LMQ/notebooks/Z_RADR_I_Z9577_20190808000200_O_DOR_SA_CAP.bin.bz2.png'
