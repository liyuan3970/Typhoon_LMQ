# %% [markdown]
# # 固定经纬度的剖面图

# %% [markdown]
# ## 山谷地形的地形波动作用

# %%
from matplotlib import cm, colors

import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from ncmaps import Cmaps

#设置rgb
fid = open('/home/liyuan3970/study_demo/met_plot/利齐马/src/radar.rgb')
data=fid.readlines()
n=len(data);
#print(n)
rgb=np.zeros((n,3))
for i in np.arange(n):
    #print(data[0].split(' '))
    rgb[i][0]=float(data[i].split(' ')[0])
    rgb[i][1]=data[i].split(' ')[1]
    rgb[i][2]=data[i].split(' ')[2]
print((rgb.shape))
#print(rgb[253])
rgb_file = 'ncl_default'
self_define_list = [24,85,132,148,158,168,188,220,240]
cmaps = Cmaps(rgb_file,self_define_list).listmap()
#cmaps= colors.ListedColormap(rgb)




fig = plt.figure(figsize=[16, 9])
from netCDF4 import Dataset
f = Dataset('/home/liyuan3970/git_demo/test_demo/meto/垂直剖面/location.nc')

lons = f.variables['lon'][:]
lats = f.variables['lat'][::]
heigh = f.variables['heigh'][:]
#print(heigh)
#print(level)
lon_sing = 97
u = f.variables['u'][:,:,lon_sing]
v = f.variables['v'][:,:,lon_sing]
w = f.variables['w'][:,:,lon_sing]
ref = f.variables['ref'][:,:,lon_sing]
geog = f.variables['geog'][:,lon_sing]
print('geog',geog.shape)
print('lats',lats.shape)
#x = f.variables['x'][:]
#print(x[90])
print(lons[lon_sing])
print(u.shape)


# Contour Plot
X, Y = np.meshgrid(lats, heigh)
Z = ref
cp = plt.contourf(X, Y, Z,cmap = cmaps)
cb = plt.colorbar(cp)


# Vector Field

x,y= np.meshgrid(lats[::2], heigh[::2])

U =v[::2,::2]
V = w[::2,::2]*20
speed = np.sqrt(U**2 + V**2)

quiv = plt.quiver(x, y, U, V,  # assign to var
           color='Black', 
           headlength=4)


#y轴的数字是x轴数字的平方
plt.plot(lats,geog,c='green',linewidth=4)
y_values = np.zeros([120,1])
plt.plot(lats,y_values,c='black')
#plt.plot(geog)
plt.show()
# Out:
# (15, 3)
# geog (120,)
# lats (120,)
# 120.61667
# (23, 120)

# %% [markdown]
# # 括苍山纬向剖面

# %%
from matplotlib import cm, colors

import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from ncmaps import Cmaps

#设置rgb
fid = open('/home/liyuan3970/study_demo/met_plot/利齐马/src/radar.rgb')
data=fid.readlines()
n=len(data);
#print(n)
rgb=np.zeros((n,3))
for i in np.arange(n):
    #print(data[0].split(' '))
    rgb[i][0]=float(data[i].split(' ')[0])
    rgb[i][1]=data[i].split(' ')[1]
    rgb[i][2]=data[i].split(' ')[2]
print((rgb.shape))
#print(rgb[253])
rgb_file = 'ncl_default'
self_define_list = [24,85,132,148,158,168,188,220,240]
cmaps = Cmaps(rgb_file,self_define_list).listmap()
#cmaps= colors.ListedColormap(rgb)




fig = plt.figure(figsize=[16, 9])
from netCDF4 import Dataset
f = Dataset('/home/liyuan3970/git_demo/test_demo/meto/垂直剖面/location.nc')

lons = f.variables['lon'][:]
lats = f.variables['lat'][::]
heigh = f.variables['heigh'][:]
#print(heigh)
#print(level)
lon_sing =115
u = f.variables['u'][:,:,lon_sing]
v = f.variables['v'][:,:,lon_sing]
w = f.variables['w'][:,:,lon_sing]
ref = f.variables['ref'][:,:,lon_sing]
geog = f.variables['geog'][:,lon_sing]
print('geog',geog.shape)
print('lats',lats.shape)
#x = f.variables['x'][:]
#print(x[90])
print(lons[lon_sing])
print(u.shape)


# Contour Plot
X, Y = np.meshgrid(lats, heigh)
Z = ref
cp = plt.contourf(X, Y, Z,cmap = cmaps)
cb = plt.colorbar(cp)


# Vector Field

x,y= np.meshgrid(lats[::2], heigh[::2])

U =v[::2,::2]
V = w[::2,::2]*20
speed = np.sqrt(U**2 + V**2)

quiv = plt.quiver(x, y, U, V,  # assign to var
           color='Black', 
           headlength=4)


#y轴的数字是x轴数字的平方
plt.plot(lats,geog,c='green',linewidth=4)
y_values = np.zeros([120,1])
plt.plot(lats,y_values,c='black')
#plt.plot(geog)
plt.show()
# Out:
# (15, 3)
# geog (120,)
# lats (120,)
# 120.916664
# (23, 120)

# %% [markdown]
# # 括苍山经向剖面

# %%
from matplotlib import cm, colors

import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from ncmaps import Cmaps

#设置rgb
fid = open('/home/liyuan3970/study_demo/met_plot/利齐马/src/radar.rgb')
data=fid.readlines()
n=len(data);
#print(n)
rgb=np.zeros((n,3))
for i in np.arange(n):
    #print(data[0].split(' '))
    rgb[i][0]=float(data[i].split(' ')[0])
    rgb[i][1]=data[i].split(' ')[1]
    rgb[i][2]=data[i].split(' ')[2]
print((rgb.shape))
#print(rgb[253])
rgb_file = 'ncl_default'
self_define_list = [24,85,132,148,158,168,188,220,240]
cmaps = Cmaps(rgb_file,self_define_list).listmap()
#cmaps= colors.ListedColormap(rgb)




fig = plt.figure(figsize=[16, 9])
from netCDF4 import Dataset
f = Dataset('/home/liyuan3970/git_demo/test_demo/meto/垂直剖面/location.nc')

lons = f.variables['lon'][:]
lats = f.variables['lat'][::]
heigh = f.variables['heigh'][:]
#print(heigh)
#print(level)
lat_sing = 108
u = f.variables['u'][:,lat_sing,:]
v = f.variables['v'][:,lat_sing,:]
w = f.variables['w'][:,lat_sing,:]
ref = f.variables['ref'][:,lat_sing,:]
geog = f.variables['geog'][lat_sing,:]
print('geog',geog.shape)
print('lats',lats.shape)
#x = f.variables['x'][:]
#print(x[90])
print(lats[lat_sing])
print(u.shape)


# Contour Plot
X, Y = np.meshgrid(lons, heigh)
Z = ref
cp = plt.contourf(X, Y, Z,cmap = cmaps)
cb = plt.colorbar(cp)


# Vector Field

x,y= np.meshgrid(lons[::5], heigh[::1])

U =u[::1,::5]
V = w[::1,::5]*15
speed = np.sqrt(U**2 + V**2)

quiv = plt.quiver(x, y, U, V,  # assign to var
           color='Black', 
           headlength=4)


#y轴的数字是x轴数字的平方
plt.plot(lons,geog,c='green',linewidth=4)
y_values = np.zeros([181,1])
plt.plot(lons,y_values,c='black')
#plt.plot(geog)
plt.show()
# Out:
# (15, 3)
# geog (181,)
# lats (120,)
# 28.815126
# (23, 181)

# %% [markdown]
# # 平原地区的降水特征

# %% [markdown]
# ## 纬向

# %%
from matplotlib import cm, colors

import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from ncmaps import Cmaps

#设置rgb
fid = open('/home/liyuan3970/study_demo/met_plot/利齐马/src/radar.rgb')
data=fid.readlines()
n=len(data);
#print(n)
rgb=np.zeros((n,3))
for i in np.arange(n):
    #print(data[0].split(' '))
    rgb[i][0]=float(data[i].split(' ')[0])
    rgb[i][1]=data[i].split(' ')[1]
    rgb[i][2]=data[i].split(' ')[2]
print((rgb.shape))
#print(rgb[253])
rgb_file = 'ncl_default'
self_define_list = [24,85,132,148,158,168,188,220,240]
cmaps = Cmaps(rgb_file,self_define_list).listmap()
#cmaps= colors.ListedColormap(rgb)




fig = plt.figure(figsize=[16, 9])
from netCDF4 import Dataset
f = Dataset('/home/liyuan3970/git_demo/test_demo/meto/垂直剖面/location.nc')

lons = f.variables['lon'][:]
lats = f.variables['lat'][::]
heigh = f.variables['heigh'][:]
#print(heigh)
#print(level)
lon_sing =145
u = f.variables['u'][:,:,lon_sing]
v = f.variables['v'][:,:,lon_sing]
w = f.variables['w'][:,:,lon_sing]
ref = f.variables['ref'][:,:,lon_sing]
geog = f.variables['geog'][:,lon_sing]
print('geog',geog.shape)
print('lats',lats.shape)
#x = f.variables['x'][:]
#print(x[90])
print(lons[lon_sing])
print(u.shape)


# Contour Plot
X, Y = np.meshgrid(lats, heigh)
Z = ref
cp = plt.contourf(X, Y, Z,cmap = cmaps)
cb = plt.colorbar(cp)


# Vector Field

x,y= np.meshgrid(lats[::5], heigh[::2])

U =v[::2,::5]
V = w[::2,::5]*10
speed = np.sqrt(U**2 + V**2)

quiv = plt.quiver(x, y, U, V,  # assign to var
           color='Black', 
           headlength=4)


#y轴的数字是x轴数字的平方
plt.plot(lats,geog,c='green',linewidth=4)
y_values = np.zeros([120,1])
plt.plot(lats,y_values,c='black')
#plt.plot(geog)
plt.show()
# Out:
# (15, 3)
# geog (120,)
# lats (120,)
# 121.416664
# (23, 120)

# %%
from matplotlib import cm, colors

import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from ncmaps import Cmaps

#设置rgb
fid = open('/home/liyuan3970/study_demo/met_plot/利齐马/src/radar.rgb')
data=fid.readlines()
n=len(data);
#print(n)
rgb=np.zeros((n,3))
for i in np.arange(n):
    #print(data[0].split(' '))
    rgb[i][0]=float(data[i].split(' ')[0])
    rgb[i][1]=data[i].split(' ')[1]
    rgb[i][2]=data[i].split(' ')[2]
print((rgb.shape))
#print(rgb[253])
rgb_file = 'ncl_default'
self_define_list = [24,85,132,148,158,168,188,220,240]
cmaps = Cmaps(rgb_file,self_define_list).listmap()
#cmaps= colors.ListedColormap(rgb)




fig = plt.figure(figsize=[16, 9])
from netCDF4 import Dataset
f = Dataset('/home/liyuan3970/git_demo/test_demo/meto/垂直剖面/location.nc')

lons = f.variables['lon'][:]
lats = f.variables['lat'][::]
heigh = f.variables['heigh'][:]
#print(heigh)
#print(level)
lat_sing = 75
u = f.variables['u'][:,lat_sing,:]
v = f.variables['v'][:,lat_sing,:]
w = f.variables['w'][:,lat_sing,:]
ref = f.variables['ref'][:,lat_sing,:]
geog = f.variables['geog'][lat_sing,:]
print('geog',geog.shape)
print('lats',lats.shape)
#x = f.variables['x'][:]
#print(x[90])
print(lats[lat_sing])
print(u.shape)


# Contour Plot
X, Y = np.meshgrid(lons, heigh)
Z = ref
cp = plt.contourf(X, Y, Z,cmap = cmaps)
cb = plt.colorbar(cp)


# Vector Field

x,y= np.meshgrid(lons[::5], heigh[::1])

U =u[::1,::5]
V = w[::1,::5]*10
speed = np.sqrt(U**2 + V**2)

quiv = plt.quiver(x, y, U, V,  # assign to var
           color='Black', 
           headlength=4)


#y轴的数字是x轴数字的平方
plt.plot(lons,geog,c='green',linewidth=4)
y_values = np.zeros([181,1])
plt.plot(lons,y_values,c='black')
#plt.plot(geog)
plt.show()
# Out:
# (15, 3)
# geog (181,)
# lats (120,)
# 28.260504
# (23, 181)
