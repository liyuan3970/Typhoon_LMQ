# %%
import numpy as np
from PIL import Image
import os
import time
import matplotlib.pyplot as plt

WIDTH = 200
HEIGHT = 200
SEQUENCE = np.array([])
BASIC_SEQUENCE = np.array([])
NEXT_SEQUENCE = np.array([])
NUMBER = 0
path = "/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/"
file = os.listdir(path)
file.sort()
print(file[0].strip(' '))
picture = Image.open(path+file[320].strip(' '))
plt.imshow(picture)
plt.show()
print(picture.size)
picture = picture.crop((0, 40, 390, 430))
picture = picture.resize((WIDTH, HEIGHT), Image.ANTIALIAS)
plt.imshow(picture)
plt.show()
# Out:
# Z_RADR_I_Z9577_20190808000200_O_DOR_SA_CAP.bin.bz2.png
# (450, 450)

# %%
import numpy as np
from PIL import Image
import os
import time
import matplotlib.pyplot as plt

WIDTH = 60
HEIGHT = 60
SEQUENCE = np.array([])
BASIC_SEQUENCE = np.array([])
NEXT_SEQUENCE = np.array([])
NUMBER = 0
path = "/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/"


def image_initialize(image):
    picture = Image.open(image)
    picture = picture.crop((0, 40, 390, 430))
    picture = picture.resize((WIDTH, HEIGHT), Image.ANTIALIAS)
    picture = picture.convert('L')
    #print(picture.size)
    data = np.array(picture.getdata())
    #print(picture.getdata().size)
    return data
files = os.listdir(path)
files.sort()
for file in files:
    # print(os.path.join(IMAGE_PATH, directories))
    # print(os.path.join(os.path.join(IMAGE_PATH, directories), file))
    #print(file)
    image_array = image_initialize(path+file.strip(' '))
    #print(file.strip(' '))
    SEQUENCE = np.append(SEQUENCE, image_array)
    NUMBER += 1
    #print(NUMBER)
    #print(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime()))

print(SEQUENCE.shape)
SEQUENCE = SEQUENCE.reshape(NUMBER, WIDTH * HEIGHT)
for i in SEQUENCE:
    for j in range(int(len(i))):
        if i[j] < 50:
            i[j] = 0


np.savez('sequence_array.npz', sequence_array=SEQUENCE)
print('Data saved.')
print(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime()))
# Out:
# (1702800,)
# Data saved.
# 2020-05-28 22:58:20

# %% [markdown]
# # 以下为绘制数据部分

# %%
import os
# %matplotlib inline
import matplotlib 
import cinrad
import matplotlib.pyplot as plt
path = "/home/liyuan3970/Data/data/meto_data/radar_typhoon_liqima/wenzhou_rada/08/"
file = os.listdir(path)[120:]
file.sort()

def plot(filename):
    file = path +filename
    f = cinrad.io.CinradReader(file)
    tilt_number = 0
    data_radius = 230
    data_dtype = 'REF' # stands for reflectivity
    rl = list(f.iter_tilt(230, 'REF'))
    #rl = list(f.iter_tilt(230, 'VEL'))
    cr = cinrad.easycalc.quick_cr(rl)
    fig = cinrad.visualize.PPI(cr, dpi=50) 
    plt.savefig('/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/'+filename+'.png')
    #plt.show()
    plt.clf()
    plt.close()

for i in file:
    plot(i)
# Out:
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/cinrad-1.4.2-py3.7-linux-x86_64.egg/cinrad/io/level2.py:355: UserWarning: Requested data range exceed max range in this tilt
#   warnings.warn("Requested data range exceed max range in this tilt")
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/cinrad-1.4.2-py3.7-linux-x86_64.egg/cinrad/io/level2.py:355: UserWarning: Requested data range exceed max range in this tilt
#   warnings.warn("Requested data range exceed max range in this tilt")
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/cinrad-1.4.2-py3.7-linux-x86_64.egg/cinrad/io/level2.py:355: UserWarning: Requested data range exceed max range in this tilt
#   warnings.warn("Requested data range exceed max range in this tilt")
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/cinrad-1.4.2-py3.7-linux-x86_64.egg/cinrad/io/level2.py:355: UserWarning: Requested data range exceed max range in this tilt
# ...

# %%
import os
# %matplotlib inline
import matplotlib 
import cinrad
import matplotlib.pyplot as plt
path = "/home/liyuan3970/Data/data/meto_data/radar_typhoon_liqima/wenzhou_rada/09/"
file = os.listdir(path)[:]
file.sort()

def plot(filename):
    file = path +filename
    f = cinrad.io.CinradReader(file)
    tilt_number = 0
    data_radius = 230
    data_dtype = 'REF' # stands for reflectivity
    rl = list(f.iter_tilt(230, 'REF'))
    #rl = list(f.iter_tilt(230, 'VEL'))
    cr = cinrad.easycalc.quick_cr(rl)
    fig = cinrad.visualize.PPI(cr, dpi=50) 
    plt.savefig('/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/'+filename+'.png')
    #plt.show()
    plt.clf()
    plt.close()

for i in file:
    plot(i)
# Out:
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/cinrad-1.4.2-py3.7-linux-x86_64.egg/cinrad/io/level2.py:355: UserWarning: Requested data range exceed max range in this tilt
#   warnings.warn("Requested data range exceed max range in this tilt")
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/cinrad-1.4.2-py3.7-linux-x86_64.egg/cinrad/io/level2.py:355: UserWarning: Requested data range exceed max range in this tilt
#   warnings.warn("Requested data range exceed max range in this tilt")
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/cinrad-1.4.2-py3.7-linux-x86_64.egg/cinrad/io/level2.py:355: UserWarning: Requested data range exceed max range in this tilt
#   warnings.warn("Requested data range exceed max range in this tilt")
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/cinrad-1.4.2-py3.7-linux-x86_64.egg/cinrad/io/level2.py:355: UserWarning: Requested data range exceed max range in this tilt
# ...

# %%
import os
# %matplotlib inline
import matplotlib 
import cinrad
import matplotlib.pyplot as plt
path = "/home/liyuan3970/Data/data/meto_data/radar_typhoon_liqima/wenzhou_rada/10/"
file = os.listdir(path)[:80]
file.sort()

def plot(filename):
    file = path +filename
    f = cinrad.io.CinradReader(file)
    tilt_number = 0
    data_radius = 230
    data_dtype = 'REF' # stands for reflectivity
    rl = list(f.iter_tilt(230, 'REF'))
    #rl = list(f.iter_tilt(230, 'VEL'))
    cr = cinrad.easycalc.quick_cr(rl)
    fig = cinrad.visualize.PPI(cr, dpi=50) 
    plt.savefig('/home/liyuan3970/Typhoon_LMQ/AI_pred_demo/data/'+filename+'.png')
    #plt.show()
    plt.clf()
    plt.close()

for i in file:
    plot(i)
# Out:
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/cinrad-1.4.2-py3.7-linux-x86_64.egg/cinrad/io/level2.py:355: UserWarning: Requested data range exceed max range in this tilt
#   warnings.warn("Requested data range exceed max range in this tilt")
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/cinrad-1.4.2-py3.7-linux-x86_64.egg/cinrad/io/level2.py:355: UserWarning: Requested data range exceed max range in this tilt
#   warnings.warn("Requested data range exceed max range in this tilt")
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/cinrad-1.4.2-py3.7-linux-x86_64.egg/cinrad/io/level2.py:355: UserWarning: Requested data range exceed max range in this tilt
#   warnings.warn("Requested data range exceed max range in this tilt")
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/cinrad-1.4.2-py3.7-linux-x86_64.egg/cinrad/io/level2.py:355: UserWarning: Requested data range exceed max range in this tilt
# ...
