# %% [markdown]
# # 台风登陆前要素值的变化特征

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib
print(matplotlib.matplotlib_fname())
path ='../src/data.xlsx'

data = pd.read_excel(path)

#print(data.iloc[:,7])
x =  data.iloc[:,0]
#x = np.arange(1, 54, 1)
# print(x)
y = data.iloc[:,1]
y1 =data.iloc[:,2]
y2 = data.iloc[:,3]
y3 =data.iloc[:,4]
y4 =data.iloc[:,5]
y5 =data.iloc[:,6]
y6 =data.iloc[:,7]
y7 =data.iloc[:,8]
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
labels = ["Vorticity Average", "Vorticity Max", "Wind  Average","Wind  Max","W  Max","W  Average","Ref  Average","Ref  Max"]
# colors = ["#8da0cb", "#fc8d62", "#66c2a5"]
x1 = [0,6,15,22,40,53]
xticks1 =['23:04','23:33','00:29','01:08','02:49','04:02']
plt.figure(figsize=(25,16))
plt.stackplot(x, y, y1, y2,y3,y4,y5,y6,y7,labels=labels,colors=None)
plt.xticks(x1,xticks1,size='large')
plt.xlabel('time')
plt.ylim(-8,20)
plt.legend(loc="upper right")

plt.show()
# Out:
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib
print(matplotlib.matplotlib_fname())
path ='../src/data.xlsx'

data = pd.read_excel(path)

#print(data.iloc[:,7])
x =  data.iloc[:,0]
#x = np.arange(1, 54, 1)
# print(x)
y = data.iloc[:,1]
y1 =data.iloc[:,2]
y2 = data.iloc[:,3]
y3 =data.iloc[:,4]
y4 =data.iloc[:,5]
y5 =data.iloc[:,6]
y6 =data.iloc[:,7]
y7 =data.iloc[:,8]

font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 18,
}
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
labels = ["Vorticity Average", "Vorticity Max","Vertical Averafe Wind "]
# colors = ["#8da0cb", "#fc8d62", "#66c2a5"]
x1 = [0,6,15,22,40,53]
xticks1 =['23:04','23:33','00:29','01:08','02:49','04:02']
plt.figure(figsize=(25,16))

plt.plot(x, y,label='Vorticity Average',linewidth =5)
plt.plot(x, y1,label='Vorticity Max',linewidth =5)
plt.plot(x, y5,label='Vertical Average Wind',linewidth =5)
#plt.plot(x, y7,label='Max Ref',linewidth =5)
y_values = np.zeros([54,1])
plt.plot(x,y_values,c='black')
plt.grid()
plt.xticks(x1,xticks1,size='large',fontsize=40)
plt.xlabel('time')
plt.ylim(-3,4)
plt.legend(loc="upper right",fontsize=30)
plt.savefig('line.png')

plt.show()
# Out:
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/matplotlibrc
